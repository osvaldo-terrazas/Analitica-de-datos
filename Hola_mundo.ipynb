# %% [markdown]
# <a href="https://colab.research.google.com/github/osvaldo-terrazas/Analitica-de-datos/blob/main/Hola_mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias numpy y matplotlib
import numpy as np
from matplotlib import pyplot as plt

# %%
#Definimos 2 arreglos de dimensión 100
ys = 200 + np.random.randn(100)
x = np.arange(0,100,1)

# %%
#Graficamos los arreglos en un plano 2D
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, facecolor = 'y', alpha = 0.8)

#Agregamos titulo a la grafica
plt.title("Sample Visualization")
plt.xlabel("eje de las x", size = 16,)
plt.ylabel("eje de las y", size = 16,)
plt.show()
